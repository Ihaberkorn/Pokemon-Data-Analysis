# %% [markdown]
# # Pokemon Ranking Data

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pandas Practice

# %%
# open excel
df = pd.read_excel(r'C:\Users\isaac\Downloads\rated_pokemon.xlsx')
# show data frame
df.head()
# Out:
#      #        Name  Stage  Generation  Type1   Type2 Legendary/Mythical  \
# 0  1.0   Bulbasaur    0.0         1.0  Grass  Poison                  N
# 1  2.0     Ivysaur    1.0         1.0  Grass  Poison                  N
# 2  3.0    Venusaur    2.0         1.0  Grass  Poison                  N
# 3  4.0  Charmander    0.0         1.0   Fire     NaN                  N
# 4  5.0  Charmeleon    1.0         1.0   Fire     NaN                  N
#
#   Final Score
# 0         4.5
# 1         4.3
# 2         2.4
# 3           4
# 4         2.6

# %%
# get info on df
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1027 entries, 0 to 1026
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   #                   1027 non-null   float64
#  1   Name                1027 non-null   str
#  2   Stage               1026 non-null   float64
#  3   Generation          1026 non-null   float64
#  4   Type1               1025 non-null   str
#  5   Type2               527 non-null    object
#  6   Legendary/Mythical  1026 non-null   str
#  7   Final Score         1027 non-null   object
# dtypes: float64(3), object(2), str(3)
# memory usage: 64.3+ KB

# %%
# drop column
df = df.drop(columns=['#'])
# set nas to none
df['Type2'] = df['Type2'].fillna('None')

# %%
# view nas and drop them
df[df.isna().any(axis=1)]
df = df.dropna()
df.head()
# Out:
#          Name  Stage  Generation  Type1   Type2 Legendary/Mythical Final Score
# 0   Bulbasaur    0.0         1.0  Grass  Poison                  N         4.5
# 1     Ivysaur    1.0         1.0  Grass  Poison                  N         4.3
# 2    Venusaur    2.0         1.0  Grass  Poison                  N         2.4
# 3  Charmander    0.0         1.0   Fire    None                  N           4
# 4  Charmeleon    1.0         1.0   Fire    None                  N         2.6

# %%
# cast final score as float
df['Final Score'] = df['Final Score'].astype(float)
# describe data
df.describe()
# Out:
#              Stage   Generation  Final Score
# count  1025.000000  1025.000000  1025.000000
# mean      0.579512     4.741463     3.126176
# std       0.688756     2.633633     1.016319
# min       0.000000     1.000000     0.800000
# 25%       0.000000     3.000000     2.500000
# 50%       0.000000     5.000000     3.250000
# 75%       1.000000     7.000000     3.880000
# max       2.000000     9.000000     5.000000

# %%
# set all scores less than 1 equal to 1
df.loc[df['Final Score'] < 1, 'Final Score'] = 1
df.loc[df['Legendary/Mythical'] == 'N', 'Legendary/Mythical'] = '0'
df.loc[df['Legendary/Mythical'] == 'Y', 'Legendary/Mythical'] = '1'
df['Legendary/Mythical'] = df['Legendary/Mythical'].astype(float)

# %%
df['Type1'].value_counts()
# Out:
# Type1
# Water       134
# Normal      118
# Grass       103
# Bug          83
# Fire         66
# Psychic      60
# Electric     59
# Rock         58
# Dark         45
# Poison       42
# Ground       40
# Fighting     40
# Dragon       37
# Steel        36
# Ghost        35
# Ice          31
# Fairy        29
# Flying        9
# Name: count, dtype: int64

# %%
df.head()
# Out:
#          Name  Stage  Generation  Type1   Type2  Legendary/Mythical  \
# 0   Bulbasaur    0.0         1.0  Grass  Poison                 0.0
# 1     Ivysaur    1.0         1.0  Grass  Poison                 0.0
# 2    Venusaur    2.0         1.0  Grass  Poison                 0.0
# 3  Charmander    0.0         1.0   Fire    None                 0.0
# 4  Charmeleon    1.0         1.0   Fire    None                 0.0
#
#    Final Score
# 0          4.5
# 1          4.3
# 2          2.4
# 3          4.0
# 4          2.6

# %% [markdown]
# ## MatPlotLib Practice
